// %%
USE {
    dependencies("org.xerial:sqlite-jdbc:3.47.1.0")
}

%use kandy
%use dataframe

// %%
import java.sql.DriverManager

val connection = DriverManager.getConnection("jdbc:sqlite:data.db")
val repositories = DataFrame.readSqlTable(connection, "Repositories")

println(repositories.columnNames())
println(repositories.columnTypes())
// Out:
// [id, size, project_id, is_disabled, is_fork, is_in_maintenance, location, is_java, is_kotlin, is_android, is_config, youngest_commit, oldest_commit]
// [kotlin.String, kotlin.Long, kotlin.String?, kotlin.Boolean, kotlin.Boolean?, kotlin.Boolean, kotlin.String, kotlin.Boolean?, kotlin.Boolean?, kotlin.Boolean?, kotlin.Boolean?, kotlin.String?, kotlin.String?]

// %%
println("Total repositories : ${repositories.rowsCount()}" )

val cumulativeRepos = repositories
    .add("year") {
        row ->
        val date = row["youngest_commit"] as? String
        date?.take(4)?.let {
            if (it.toInt() < 2020) "2019" else it
        } ?: "2019"
    }
    .groupBy("year")
    .aggregate {
        count() into "yearly_count"
    }
    .sortBy("year")
    .insert("yearly_cumulative") {  "yearly_count"<Int>()}.after("yearly_count")
    .cumSum("yearly_cumulative")

cumulativeRepos.plot {
    bars {
        x("year")
        y("yearly_count")
        fillColor = Color.PEACH

    }
    line {
        x("year"){
            axis.name = "Calendar year"
        }
        y("yearly_cumulative"){
            axis.name = "Number of repositories added"
        }
        color = Color.ORANGE

    }
    layout {
        subtitle = "Total number of repositories per year"
    }

}
// Out:
// Total repositories : 39987
//             <iframe src='about:blank' style='border:none !important;' width='600' height='400' srcdoc="&lt;html lang=&quot;en&quot;>
//    &lt;head>
//        &lt;meta charset=&quot;UTF-8&quot;>
//        &lt;style> html, body { margin: 0; overflow: hidden; } &lt;/style>
//        &lt;script type=&quot;text/javascript&quot; data-lets-plot-script=&quot;library&quot; src=&quot;https://cdn.jsdelivr.net/gh/JetBrains/lets-plot@v4.3.3/js-package/distr/lets-plot.min.js&quot;>&lt;/script>
//    &lt;/head>
//    &lt;body>
//           &lt;div id=&quot;oSkBrk&quot;>&lt;/div>
//    &lt;script type=&quot;text/javascript&quot; data-lets-plot-script=&quot;plot&quot;>
//        var plotSpec={
// &quot;mapping&quot;:{
// },
// &quot;data&quot;:{
// &quot;yearly_cumulative&quot;:[15785.0,16772.0,18837.0,21995.0,28053.0,38505.0,39987.0],
// &quot;year&quot;:[&quot;2019&quot;,&quot;2020&quot;,&quot;2021&quot;,&quot;2022&quot;,&quot;2023&quot;,&quot;2024&quot;,&quot;2025&quot;],
// &quot;yearly_count&quot;:[15785.0,987.0,2065.0,3158.0,6058.0,10452.0,1482.0]
// },
// &quot;kind&quot;:&quot;plot&quot;,
// &quot;scales&quot;:[{
// &quot;aesthetic&quot;:&quot;x&quot;,
// &quot;discrete&quot;:true
// },{
// &quot;aesthetic&quot;:&quot;y&quot;,
// &quot;limits&quot;:[null,null]
// },{
// &quot;aesthetic&quot;:&quot;x&quot;,
// &quot;discrete&quot;:true,
// &quot;name&quot;:&quot;Calendar year&quot;
// },{
// &quot;aesthetic&quot;:&quot;y&quot;,
// &quot;name&quot;:&quot;Number of repositories added&quot;,
// &quot;limits&quot;:[null,null]
// }],
// &quot;layers&quot;:[{
// &quot;mapping&quot;:{
// &quot;x&quot;:&quot;year&quot;,
// &quot;y&quot;:&quot;yearly_count&quot;
// },
// &quot;stat&quot;:&quot;identity&quot;,
// &quot;sampling&quot;:&quot;none&quot;,
// &quot;position&quot;:&quot;dodge&quot;,
// &quot;geom&quot;:&quot;bar&quot;,
// &quot;fill&quot;:&quot;#ffe5b4&quot;,
// &quot;data&quot;:{
// }
// },{
// &quot;mapping&quot;:{
// &quot;x&quot;:&quot;year&quot;,
// &quot;y&quot;:&quot;yearly_cumulative&quot;
// },
// &quot;stat&quot;:&quot;identity&quot;,
// &quot;color&quot;:&quot;#fc8452&quot;,
// &quot;sampling&quot;:&quot;none&quot;,
// &quot;position&quot;:&quot;identity&quot;,
// &quot;geom&quot;:&quot;line&quot;,
// &quot;data&quot;:{
// }
// }]
// };
//        var plotContainer = document.getElementById(&quot;oSkBrk&quot;);
//        LetsPlot.buildPlotFromProcessedSpecs(plotSpec, -1, -1, plotContainer);
//    &lt;/script>
//    &lt;/body>
// &lt;/html>"></iframe>            <svg xmlns="http://www.w3.org/2000/svg" xmlns:xlink="http://www.w3.org/1999/xlink" display="block" class="plt-container" id=a2e39c81-945f-4176-80f0-d154a4fdef73 width="100%" height="100%" style="max-width: 600.0px; max-height: 400.0px;" viewBox="0 0 600.0 400.0" preserveAspectRatio="xMinYMin meet">
//   <style type="text/css">
//   .plt-container {
//    font-family: Lucida Grande, sans-serif;
//    user-select: none;
//    -webkit-user-select: none;
//    -moz-user-select: none;
//    -ms-user-select: none;
// }
// text {
//    text-rendering: optimizeLegibility;
// }
// #pinXcCv .plot-title {
//    fill: #474747;
//    font-family: Lucida Grande, sans-serif;
//    font-size: 16.0px;
//    font-weight: normal;
//    font-style: normal;
// }
// #pinXcCv .plot-subtitle {
//    fill: #474747;
//    font-family: Lucida Grande, sans-serif;
//    font-size: 15.0px;
//    font-weight: normal;
//    font-style: normal;
// }
// #pinXcCv .plot-caption {
//    fill: #474747;
//    font-family: Lucida Grande, sans-serif;
//    font-size: 13.0px;
//    font-weight: normal;
//    font-style: normal;
// }
// #pinXcCv .legend-title {
//    fill: #474747;
//    font-family: Lucida Grande, sans-serif;
//    font-size: 15.0px;
//    font-weight: normal;
//    font-style: normal;
// }
// #pinXcCv .legend-item {
//    fill: #474747;
//    font-family: Lucida Grande, sans-serif;
//    font-size: 13.0px;
//    font-weight: normal;
//    font-style: normal;
// }
// #pinXcCv .axis-title-x {
//    fill: #474747;
//    font-family: Lucida Grande, sans-serif;
//    font-size: 15.0px;
//    font-weight: normal;
//    font-style: normal;
// }
// #pinXcCv .axis-text-x {
//    fill: #474747;
//    font-family: Lucida Grande, sans-serif;
//    font-size: 13.0px;
//    font-weight: normal;
//    font-style: normal;
// }
// #ddZzui4 .axis-tooltip-text-x {
//    fill: #ffffff;
//    font-family: Lucida Grande, sans-serif;
//    font-size: 13.0px;
//    font-weight: normal;
//    font-style: normal;
// }
// #pinXcCv .axis-title-y {
//    fill: #474747;
//    font-family: Lucida Grande, sans-serif;
//    font-size: 15.0px;
//    font-weight: normal;
//    font-style: normal;
// }
// #pinXcCv .axis-text-y {
//    fill: #474747;
//    font-family: Lucida Grande, sans-serif;
//    font-size: 13.0px;
//    font-weight: normal;
//    font-style: normal;
// }
// #ddZzui4 .axis-tooltip-text-y {
//    fill: #ffffff;
//    font-family: Lucida Grande, sans-serif;
//    font-size: 13.0px;
//    font-weight: normal;
//    font-style: normal;
// }
// #pinXcCv .facet-strip-text-x {
//    fill: #474747;
//    font-family: Lucida Grande, sans-serif;
//    font-size: 13.0px;
//    font-weight: normal;
//    font-style: normal;
// }
// #pinXcCv .facet-strip-text-y {
//    fill: #474747;
//    font-family: Lucida Grande, sans-serif;
//    font-size: 13.0px;
//    font-weight: normal;
//    font-style: normal;
// }
// #ddZzui4 .tooltip-text {
//    fill: #474747;
//    font-family: Lucida Grande, sans-serif;
//    font-size: 13.0px;
//    font-weight: normal;
//    font-style: normal;
// }
// #ddZzui4 .tooltip-title {
//    fill: #474747;
//    font-family: Lucida Grande, sans-serif;
//    font-size: 13.0px;
//    font-weight: bold;
//    font-style: normal;
// }
// #ddZzui4 .tooltip-label {
//    fill: #474747;
//    font-family: Lucida Grande, sans-serif;
//    font-size: 13.0px;
//    font-weight: bold;
//    font-style: normal;
// }
//
//   </style>
//   <g id="pinXcCv">
//     <path fill-rule="evenodd" fill="rgb(255,255,255)" fill-opacity="1.0" d="M0.0 0.0 L0.0 400.0 L600.0 400.0 L600.0 0.0 Z">
//     </path>
//     <g transform="translate(29.5 6.5 ) ">
//       <g>
//         <g transform="translate(50.97651758668602 0.0 ) ">
//           <g>
//             <line x1="45.68017309159645" y1="0.0" x2="45.68017309159645" y2="341.0" stroke="rgb(233,233,233)" stroke-opacity="1.0" stroke-width="1.0" fill="none">
//             </line>
//             <line x1="115.95736246328329" y1="0.0" x2="115.95736246328329" y2="341.0" stroke="rgb(233,233,233)" stroke-opacity="1.0" stroke-width="1.0" fill="none">
//             </line>
//             <line x1="186.23455183497015" y1="0.0" x2="186.23455183497015" y2="341.0" stroke="rgb(233,233,233)" stroke-opacity="1.0" stroke-width="1.0" fill="none">
//             </line>
//             <line x1="256.51174120665695" y1="0.0" x2="256.51174120665695" y2="341.0" stroke="rgb(233,233,233)" stroke-opacity="1.0" stroke-width="1.0" fill="none">
//             </line>
//             <line x1="326.7889305783438" y1="0.0" x2="326.7889305783438" y2="341.0" stroke="rgb(233,233,233)" stroke-opacity="1.0" stroke-width="1.0" fill="none">
//             </line>
//             <line x1="397.06611995003067" y1="0.0" x2="397.06611995003067" y2="341.0" stroke="rgb(233,233,233)" stroke-opacity="1.0" stroke-width="1.0" fill="none">
//             </line>
//             <line x1="467.34330932171747" y1="0.0" x2="467.34330932171747" y2="341.0" stroke="rgb(233,233,233)" stroke-opacity="1.0" stroke-width="1.0" fill="none">
//             </line>
//           </g>
//         </g>
//         <g transform="translate(50.97651758668602 0.0 ) ">
//           <g>
//             <line x1="0.0" y1="341.0" x2="513.023482413314" y2="341.0" stroke="rgb(233,233,233)" stroke-opacity="1.0" stroke-width="1.0" fill="none">
//             </line>
//             <line x1="0.0" y1="300.39156416311494" x2="513.023482413314" y2="300.39156416311494" stroke="rgb(233,233,233)" stroke-opacity="1.0" stroke-width="1.0" fill="none">
//             </line>
//             <line x1="0.0" y1="259.7831283262298" x2="513.023482413314" y2="259.7831283262298" stroke="rgb(233,233,233)" stroke-opacity="1.0" stroke-width="1.0" fill="none">
//             </line>
//             <line x1="0.0" y1="219.17469248934475" x2="513.023482413314" y2="219.17469248934475" stroke="rgb(233,233,233)" stroke-opacity="1.0" stroke-width="1.0" fill="none">
//             </line>
//             <line x1="0.0" y1="178.56625665245966" x2="513.023482413314" y2="178.56625665245966" stroke="rgb(233,233,2

// %%
val active_repositories = repositories
    .filter { it["is_disabled"] != 1 && it["is_in_maintenance"] != 1 && it["is_fork"] != 1 }
    .filter { it["oldest_commit"] != null && it["youngest_commit"] != null }

val config_active_repositories = active_repositories
    .filter { it["is_config"] != 1 }

val jvm_active_repositories = active_repositories
    .filter { it["is_java"] == 1 || it["is_android"] == 1 || it["is_kotlin"] == 1  }

val other_active_repositories = active_repositories.rowsCount() - config_active_repositories.rowsCount() - jvm_active_repositories.rowsCount()

val repository_type by columnOf("Configuration Repository", "JVM Repository", "Other")
val count by columnOf(config_active_repositories.rowsCount(), jvm_active_repositories.rowsCount(), other_active_repositories)
val df = dataFrameOf(repository_type, count)

df.plot {
    pie {
        slice(count)
        fillColor(repository_type) {
            scale = categorical(
                "Configuration Repository" to Color.ORANGE,
                "JVM Repository" to Color.PURPLE,
                "Other" to Color.GREEN
            )
        }
        size = 33.0
        hole = 0.8
        alpha = 0.8
    }
    layout {
        style(Style.Void)
    }
}
// Out:
//             <iframe src='about:blank' style='border:none !important;' width='600' height='400' srcdoc="&lt;html lang=&quot;en&quot;>
//    &lt;head>
//        &lt;meta charset=&quot;UTF-8&quot;>
//        &lt;style> html, body { margin: 0; overflow: hidden; } &lt;/style>
//        &lt;script type=&quot;text/javascript&quot; data-lets-plot-script=&quot;library&quot; src=&quot;https://cdn.jsdelivr.net/gh/JetBrains/lets-plot@v4.3.3/js-package/distr/lets-plot.min.js&quot;>&lt;/script>
//    &lt;/head>
//    &lt;body>
//           &lt;div id=&quot;OhUysa&quot;>&lt;/div>
//    &lt;script type=&quot;text/javascript&quot; data-lets-plot-script=&quot;plot&quot;>
//        var plotSpec={
// &quot;mapping&quot;:{
// },
// &quot;data&quot;:{
// &quot;count&quot;:[5498.0,5497.0,13962.0],
// &quot;repository_type&quot;:[&quot;Configuration Repository&quot;,&quot;JVM Repository&quot;,&quot;Other&quot;]
// },
// &quot;kind&quot;:&quot;plot&quot;,
// &quot;scales&quot;:[{
// &quot;aesthetic&quot;:&quot;fill&quot;,
// &quot;values&quot;:[&quot;#fc8452&quot;,&quot;#9a60b4&quot;,&quot;#3ba272&quot;],
// &quot;limits&quot;:[&quot;Configuration Repository&quot;,&quot;JVM Repository&quot;,&quot;Other&quot;]
// }],
// &quot;layers&quot;:[{
// &quot;hole&quot;:0.8,
// &quot;mapping&quot;:{
// &quot;slice&quot;:&quot;count&quot;,
// &quot;fill&quot;:&quot;repository_type&quot;
// },
// &quot;stat&quot;:&quot;identity&quot;,
// &quot;size&quot;:33.0,
// &quot;sampling&quot;:&quot;none&quot;,
// &quot;alpha&quot;:0.8,
// &quot;position&quot;:&quot;identity&quot;,
// &quot;geom&quot;:&quot;pie&quot;,
// &quot;data&quot;:{
// }
// }],
// &quot;theme&quot;:{
// &quot;name&quot;:&quot;classic&quot;,
// &quot;axis&quot;:{
// &quot;blank&quot;:true
// },
// &quot;line&quot;:{
// &quot;blank&quot;:true
// },
// &quot;axis_ontop&quot;:false,
// &quot;axis_ontop_y&quot;:false,
// &quot;axis_ontop_x&quot;:false
// }
// };
//        var plotContainer = document.getElementById(&quot;OhUysa&quot;);
//        LetsPlot.buildPlotFromProcessedSpecs(plotSpec, -1, -1, plotContainer);
//    &lt;/script>
//    &lt;/body>
// &lt;/html>"></iframe>            <svg xmlns="http://www.w3.org/2000/svg" xmlns:xlink="http://www.w3.org/1999/xlink" display="block" class="plt-container" id=0dd978b0-20e9-4002-9c2c-7689b27d88cf width="100%" height="100%" style="max-width: 600.0px; max-height: 400.0px;" viewBox="0 0 600.0 400.0" preserveAspectRatio="xMinYMin meet">
//   <style type="text/css">
//   .plt-container {
//    font-family: Lucida Grande, sans-serif;
//    user-select: none;
//    -webkit-user-select: none;
//    -moz-user-select: none;
//    -ms-user-select: none;
// }
// text {
//    text-rendering: optimizeLegibility;
// }
// #pVa68Ua .plot-title {
//    fill: #474747;
//    font-family: Lucida Grande, sans-serif;
//    font-size: 16.0px;
//    font-weight: normal;
//    font-style: normal;
// }
// #pVa68Ua .plot-subtitle {
//    fill: #474747;
//    font-family: Lucida Grande, sans-serif;
//    font-size: 15.0px;
//    font-weight: normal;
//    font-style: normal;
// }
// #pVa68Ua .plot-caption {
//    fill: #474747;
//    font-family: Lucida Grande, sans-serif;
//    font-size: 13.0px;
//    font-weight: normal;
//    font-style: normal;
// }
// #pVa68Ua .legend-title {
//    fill: #474747;
//    font-family: Lucida Grande, sans-serif;
//    font-size: 15.0px;
//    font-weight: normal;
//    font-style: normal;
// }
// #pVa68Ua .legend-item {
//    fill: #474747;
//    font-family: Lucida Grande, sans-serif;
//    font-size: 13.0px;
//    font-weight: normal;
//    font-style: normal;
// }
// #pVa68Ua .axis-title-x {
//    fill: #474747;
//    font-family: Lucida Grande, sans-serif;
//    font-size: 15.0px;
//    font-weight: normal;
//    font-style: normal;
// }
// #pVa68Ua .axis-text-x {
//    fill: #474747;
//    font-family: Lucida Grande, sans-serif;
//    font-size: 13.0px;
//    font-weight: normal;
//    font-style: normal;
// }
// #dwrWfb9 .axis-tooltip-text-x {
//    fill: #ffffff;
//    font-family: Lucida Grande, sans-serif;
//    font-size: 13.0px;
//    font-weight: normal;
//    font-style: normal;
// }
// #pVa68Ua .axis-title-y {
//    fill: #474747;
//    font-family: Lucida Grande, sans-serif;
//    font-size: 15.0px;
//    font-weight: normal;
//    font-style: normal;
// }
// #pVa68Ua .axis-text-y {
//    fill: #474747;
//    font-family: Lucida Grande, sans-serif;
//    font-size: 13.0px;
//    font-weight: normal;
//    font-style: normal;
// }
// #dwrWfb9 .axis-tooltip-text-y {
//    fill: #ffffff;
//    font-family: Lucida Grande, sans-serif;
//    font-size: 13.0px;
//    font-weight: normal;
//    font-style: normal;
// }
// #pVa68Ua .facet-strip-text-x {
//    fill: #474747;
//    font-family: Lucida Grande, sans-serif;
//    font-size: 13.0px;
//    font-weight: normal;
//    font-style: normal;
// }
// #pVa68Ua .facet-strip-text-y {
//    fill: #474747;
//    font-family: Lucida Grande, sans-serif;
//    font-size: 13.0px;
//    font-weight: normal;
//    font-style: normal;
// }
// #dwrWfb9 .tooltip-text {
//    fill: #474747;
//    font-family: Lucida Grande, sans-serif;
//    font-size: 13.0px;
//    font-weight: normal;
//    font-style: normal;
// }
// #dwrWfb9 .tooltip-title {
//    fill: #474747;
//    font-family: Lucida Grande, sans-serif;
//    font-size: 13.0px;
//    font-weight: bold;
//    font-style: normal;
// }
// #dwrWfb9 .tooltip-label {
//    fill: #474747;
//    font-family: Lucida Grande, sans-serif;
//    font-size: 13.0px;
//    font-weight: bold;
//    font-style: normal;
// }
//
//   </style>
//   <g id="pVa68Ua">
//     <path fill-rule="evenodd" fill="rgb(255,255,255)" fill-opacity="1.0" d="M0.0 0.0 L0.0 400.0 L600.0 400.0 L600.0 0.0 Z">
//     </path>
//     <g transform="translate(6.5 6.5 ) ">
//       <g>
//         <g transform="">
//           <g>
//           </g>
//         </g>
//         <g transform="">
//           <g>
//           </g>
//         </g>
//         <g transform="translate(0.0 387.0 ) ">
//         </g>
//         <g transform="">
//         </g>
//       </g>
//       <g clip-path="url(#cO1lJiS)" clip-bounds-jfx="[rect (0.0, 0.0), (370.9052898809987, 387.0)]">
//         <g transform="">
//           <g>
//             <g>
//               <g>
//                 <path d="M55.744502190021876 169.00923226557066 L23.31746650240251 162.88654033196332 A165.0 165.0 0.0 0 1 185.4526449404993 28.5 L185.4526449404993 61.5 A132.0 132.0 0.0 0 0 55.744502190021876 169.00923226557066 " fill="rgb(252,132,82)" stroke-width="1.0" fill-opacity="0.8">
//                 </path>
//               </g>
//               <g>
//                 <path d="M185.4526449404993 61.5 L185.4526449404993 28.5 A165.0 165.0 0.0 0 1 347.58011098226126 162.84572207868317 L315.15461777390885 168.97657766294654 A132.0 132.0 0.0 0 0 185.4526449404993 61.5 " fill="rgb(154,96,180)" stroke-width="1.0" fill-opacity="0.8">
//                 </path>
//               </g>
//               <g>
//                 <path d="M315.15461777390885 168.97657766294654 L347.58011098226126 162.84572207868317 A165.0 165.0 0.0 1 1 23.31746650240251 162.88654033196337 L55.744502190021876 169.0092322655707 A132.0 132.0 0.0 1 0 315.15461777390885 168.97657766294654 " fill="rgb(59,162,114)" stroke-width="1.0" fill-opacity="0.8">
//                 </path>
//               </g>
//               <g>
//                 <path d="M23.31746650240251 162.88654033196332 A165.0 165.0 0.0 0 1 185.4526449404993 28.5 M185.4526449404993 61.5 A132.0 132.0 0.0 0 0 55.744502190021876 169.00923226557066 " fill="none" stroke-width="0.75" stroke="rgb(255,255,255)" stroke-opacity="1.0">
//                 </path>
//               </g>
//               <g>
//                 <path d="M185.4526449404993 28.5 A165.0 165.0 0.0 0 1 347.58011098226126 162.84572207868317 M315.15461777390885 168.97657766294654 A132.0 132.0 0.0 0 0 185.4526449404993 61.5 " fill="none" stroke-width="0.75" stroke="rgb(255,255,255)" stroke-opacity="1.0">
//                 </path>
//               </g>
//               <g>
//                 <path d="M347.58011098226126 162.84572207868317 A165.0 165.0 0.0 1 1 23.31746650240251 162.88654033196337 M55.744502190021876 169.0092322655707 A132.0 132.0 0.0 1 0 315.15461777390885 168.97657766294654 " fill="none" stroke-width="0.75" stroke="rgb(255,255,255)" stroke-opacity="1.0">
//                 </path>
//               </g>
//               <g>
//                 <path d="M56.11299123192666 169.07880831027074 L22.94897746049776 162.81696428726326 M185.4526449404993 61.875 L185.4526449404993 28.125

// %%
val kotlin_active_repos = jvm_active_repositories
    .filter { it["is_kotlin"] != 0}

println("Found ${jvm_active_repositories.rowsCount()} JVM repos, of which ${kotlin_active_repos.rowsCount()} repos with Kotlin inside")


val cumulativeJvmRepos = jvm_active_repositories
    .add("year") {
            row ->
        val date = row["oldest_commit"] as? String
        date?.take(4)?.let {
            if (it.toInt() < 2020) "2019" else it
        } ?: "2019"
    }
    .groupBy("year")
    .aggregate {
        count() into "yearly_count"
    }
    .sortBy("year")
    .insert("yearly_cumulative") {  "yearly_count"<Int>()}.after("yearly_count")
    .cumSum("yearly_cumulative")

val cumulativeKotlinRepos = kotlin_active_repos
    .add("year") {
            row ->
        val date = row["oldest_commit"] as? String
        date?.take(4)?.let {
            if (it.toInt() < 2020) "2019" else it
        } ?: "2019"
    }
    .groupBy("year")
    .aggregate {
        count() into "yearly_count"
    }
    .sortBy("year")
    .insert("yearly_cumulative") {  "yearly_count"<Int>()}.after("yearly_count")
    .cumSum("yearly_cumulative")

//println(cumulativeJvmRepos.filter { it["year"] == "2019" }.rowsCount())

println("-------------")
cumulativeJvmRepos.forEach {
    println("${it["year"]} ${it["yearly_count"]} ${it["yearly_cumulative"]}")
}
println("-------------")
cumulativeKotlinRepos.forEach {
    println("${it["year"]} ${it["yearly_count"]} ${it["yearly_cumulative"]}")
}
println("-------------")
// Out:
// Found 5497 JVM repos, of which 435 repos with Kotlin inside
// -------------
// 2019 2195 2195
// 2020 512 2707
// 2021 637 3344
// 2022 699 4043
// 2023 884 4927
// 2024 570 5497
// -------------
// 2019 144 144
// 2020 33 177
// 2021 53 230
// 2022 47 277
// 2023 95 372
// 2024 63 435
// -------------

// %%
val years = listOf("2019", "2020", "2021", "2022", "2023", "2024")
val jvmPlotValues = years.map { year -> cumulativeJvmRepos.filter { it["year"] == year }[0]["yearly_count"] }
val kotlinPlotValues = years.map { year -> cumulativeKotlinRepos.filter { it["year"] == year }[0]["yearly_count"] }


val dataset = dataFrameOf(
    "year" to years,
    "JVM" to jvmPlotValues,
    "Kotlin" to kotlinPlotValues,
).gather("JVM", "Kotlin").into("type", "amount")

dataset.groupBy("type").plot {
    layout.title = "Kotlin adoption in JVM repositories"
     bars {
            x("year")
            y("amount")
            fillColor("type") {
                scale = categorical(
                    "JVM" to Color.ORANGE,
                    "Kotlin" to Color.PURPLE,
                )
            }
        }
}
// Out:
//             <iframe src='about:blank' style='border:none !important;' width='600' height='400' srcdoc="&lt;html lang=&quot;en&quot;>
//    &lt;head>
//        &lt;meta charset=&quot;UTF-8&quot;>
//        &lt;style> html, body { margin: 0; overflow: hidden; } &lt;/style>
//        &lt;script type=&quot;text/javascript&quot; data-lets-plot-script=&quot;library&quot; src=&quot;https://cdn.jsdelivr.net/gh/JetBrains/lets-plot@v4.3.3/js-package/distr/lets-plot.min.js&quot;>&lt;/script>
//    &lt;/head>
//    &lt;body>
//           &lt;div id=&quot;MEe4cT&quot;>&lt;/div>
//    &lt;script type=&quot;text/javascript&quot; data-lets-plot-script=&quot;plot&quot;>
//        var plotSpec={
// &quot;ggtitle&quot;:{
// &quot;text&quot;:&quot;Kotlin adoption in JVM repositories&quot;
// },
// &quot;mapping&quot;:{
// },
// &quot;data&quot;:{
// &quot;amount&quot;:[2195.0,512.0,637.0,699.0,884.0,570.0,144.0,33.0,53.0,47.0,95.0,63.0],
// &quot;&amp;merged_groups&quot;:[&quot;JVM&quot;,&quot;JVM&quot;,&quot;JVM&quot;,&quot;JVM&quot;,&quot;JVM&quot;,&quot;JVM&quot;,&quot;Kotlin&quot;,&quot;Kotlin&quot;,&quot;Kotlin&quot;,&quot;Kotlin&quot;,&quot;Kotlin&quot;,&quot;Kotlin&quot;],
// &quot;year&quot;:[&quot;2019&quot;,&quot;2020&quot;,&quot;2021&quot;,&quot;2022&quot;,&quot;2023&quot;,&quot;2024&quot;,&quot;2019&quot;,&quot;2020&quot;,&quot;2021&quot;,&quot;2022&quot;,&quot;2023&quot;,&quot;2024&quot;],
// &quot;type&quot;:[&quot;JVM&quot;,&quot;JVM&quot;,&quot;JVM&quot;,&quot;JVM&quot;,&quot;JVM&quot;,&quot;JVM&quot;,&quot;Kotlin&quot;,&quot;Kotlin&quot;,&quot;Kotlin&quot;,&quot;Kotlin&quot;,&quot;Kotlin&quot;,&quot;Kotlin&quot;]
// },
// &quot;kind&quot;:&quot;plot&quot;,
// &quot;scales&quot;:[{
// &quot;aesthetic&quot;:&quot;x&quot;,
// &quot;discrete&quot;:true
// },{
// &quot;aesthetic&quot;:&quot;y&quot;,
// &quot;limits&quot;:[null,null]
// },{
// &quot;aesthetic&quot;:&quot;fill&quot;,
// &quot;values&quot;:[&quot;#fc8452&quot;,&quot;#9a60b4&quot;],
// &quot;limits&quot;:[&quot;JVM&quot;,&quot;Kotlin&quot;]
// }],
// &quot;layers&quot;:[{
// &quot;mapping&quot;:{
// &quot;x&quot;:&quot;year&quot;,
// &quot;y&quot;:&quot;amount&quot;,
// &quot;fill&quot;:&quot;type&quot;,
// &quot;group&quot;:&quot;&amp;merged_groups&quot;
// },
// &quot;stat&quot;:&quot;identity&quot;,
// &quot;sampling&quot;:&quot;none&quot;,
// &quot;position&quot;:&quot;dodge&quot;,
// &quot;geom&quot;:&quot;bar&quot;,
// &quot;data&quot;:{
// }
// }]
// };
//        var plotContainer = document.getElementById(&quot;MEe4cT&quot;);
//        LetsPlot.buildPlotFromProcessedSpecs(plotSpec, -1, -1, plotContainer);
//    &lt;/script>
//    &lt;/body>
// &lt;/html>"></iframe>            <svg xmlns="http://www.w3.org/2000/svg" xmlns:xlink="http://www.w3.org/1999/xlink" display="block" class="plt-container" id=cb04ea71-8268-42a0-9dd4-a3b13e86b778 width="100%" height="100%" style="max-width: 600.0px; max-height: 400.0px;" viewBox="0 0 600.0 400.0" preserveAspectRatio="xMinYMin meet">
//   <style type="text/css">
//   .plt-container {
//    font-family: Lucida Grande, sans-serif;
//    user-select: none;
//    -webkit-user-select: none;
//    -moz-user-select: none;
//    -ms-user-select: none;
// }
// text {
//    text-rendering: optimizeLegibility;
// }
// #pH015jE .plot-title {
//    fill: #474747;
//    font-family: Lucida Grande, sans-serif;
//    font-size: 16.0px;
//    font-weight: normal;
//    font-style: normal;
// }
// #pH015jE .plot-subtitle {
//    fill: #474747;
//    font-family: Lucida Grande, sans-serif;
//    font-size: 15.0px;
//    font-weight: normal;
//    font-style: normal;
// }
// #pH015jE .plot-caption {
//    fill: #474747;
//    font-family: Lucida Grande, sans-serif;
//    font-size: 13.0px;
//    font-weight: normal;
//    font-style: normal;
// }
// #pH015jE .legend-title {
//    fill: #474747;
//    font-family: Lucida Grande, sans-serif;
//    font-size: 15.0px;
//    font-weight: normal;
//    font-style: normal;
// }
// #pH015jE .legend-item {
//    fill: #474747;
//    font-family: Lucida Grande, sans-serif;
//    font-size: 13.0px;
//    font-weight: normal;
//    font-style: normal;
// }
// #pH015jE .axis-title-x {
//    fill: #474747;
//    font-family: Lucida Grande, sans-serif;
//    font-size: 15.0px;
//    font-weight: normal;
//    font-style: normal;
// }
// #pH015jE .axis-text-x {
//    fill: #474747;
//    font-family: Lucida Grande, sans-serif;
//    font-size: 13.0px;
//    font-weight: normal;
//    font-style: normal;
// }
// #d68ymBQ .axis-tooltip-text-x {
//    fill: #ffffff;
//    font-family: Lucida Grande, sans-serif;
//    font-size: 13.0px;
//    font-weight: normal;
//    font-style: normal;
// }
// #pH015jE .axis-title-y {
//    fill: #474747;
//    font-family: Lucida Grande, sans-serif;
//    font-size: 15.0px;
//    font-weight: normal;
//    font-style: normal;
// }
// #pH015jE .axis-text-y {
//    fill: #474747;
//    font-family: Lucida Grande, sans-serif;
//    font-size: 13.0px;
//    font-weight: normal;
//    font-style: normal;
// }
// #d68ymBQ .axis-tooltip-text-y {
//    fill: #ffffff;
//    font-family: Lucida Grande, sans-serif;
//    font-size: 13.0px;
//    font-weight: normal;
//    font-style: normal;
// }
// #pH015jE .facet-strip-text-x {
//    fill: #474747;
//    font-family: Lucida Grande, sans-serif;
//    font-size: 13.0px;
//    font-weight: normal;
//    font-style: normal;
// }
// #pH015jE .facet-strip-text-y {
//    fill: #474747;
//    font-family: Lucida Grande, sans-serif;
//    font-size: 13.0px;
//    font-weight: normal;
//    font-style: normal;
// }
// #d68ymBQ .tooltip-text {
//    fill: #474747;
//    font-family: Lucida Grande, sans-serif;
//    font-size: 13.0px;
//    font-weight: normal;
//    font-style: normal;
// }
// #d68ymBQ .tooltip-title {
//    fill: #474747;
//    font-family: Lucida Grande, sans-serif;
//    font-size: 13.0px;
//    font-weight: bold;
//    font-style: normal;
// }
// #d68ymBQ .tooltip-label {
//    fill: #474747;
//    font-family: Lucida Grande, sans-serif;
//    font-size: 13.0px;
//    font-weight: bold;
//    font-style: normal;
// }
//
//   </style>
//   <g id="pH015jE">
//     <path fill-rule="evenodd" fill="rgb(255,255,255)" fill-opacity="1.0" d="M0.0 0.0 L0.0 400.0 L600.0 400.0 L600.0 0.0 Z">
//     </path>
//     <g transform="translate(29.5 26.5 ) ">
//       <g>
//         <g transform="translate(42.99591213121782 0.0 ) ">
//           <g>
//             <line x1="44.67300824577386" y1="0.0" x2="44.67300824577386" y2="321.0" stroke="rgb(233,233,233)" stroke-opacity="1.0" stroke-width="1.0" fill="none">
//             </line>
//             <line x1="113.4007132392721" y1="0.0" x2="113.4007132392721" y2="321.0" stroke="rgb(233,233,233)" stroke-opacity="1.0" stroke-width="1.0" fill="none">
//             </line>
//             <line x1="182.12841823277034" y1="0.0" x2="182.12841823277034" y2="321.0" stroke="rgb(233,233,233)" stroke-opacity="1.0" stroke-width="1.0" fill="none">
//             </line>
//             <line x1="250.85612322626855" y1="0.0" x2="250.85612322626855" y2="321.0" stroke="rgb(233,233,233)" stroke-opacity="1.0" stroke-width="1.0" fill="none">
//             </line>
//             <line x1="319.5838282197668" y1="0.0" x2="319.5838282197668" y2="321.0" stroke="rgb(233,233,233)" stroke-opacity="1.0" stroke-width="1.0" fill="none">
//             </line>
//             <line x1="388.3115332132651" y1="0.0" x2="388.3115332132651" y2="321.0" stroke="rgb(233,233,233)" stroke-opacity="1.0" stroke-width="1.0" fill="none">
//             </line>
//           </g>
//         </g>
//         <g transform="translate(42.99591213121782 0.0 ) ">
//           <g>
//             <line x1="0.0" y1="321.0" x2="432.9845414590389" y2="321.0" stroke="rgb(233,233,233)" stroke-opacity="1.0" stroke-width="1.0" fill="none">
//             </line>
//             <line x1="0.0" y1="251.3612105434429" x2="432.9845414590389" y2="251.3612105434429" stroke="rgb(233,233,233)" stroke-opacity="1.0" stroke-width="1.0" fill="none">
//             </line>
//             <line x1="0.0" y1="181.7224210868858" x2="432.9845414590389" y2="181.7224210868858" stroke="rgb(233,233,233)" stroke-opacity="1.0" stroke-width="1.0" fill="none">
//             </line>
//             <line x1="0.0" y1="112.08363163032868" x2="432.9845414590389" y2="112.08363163032868" stroke="rgb(233,233,233)" stroke-opacity="1.0" stroke-width="1.0" fill="none">
//             </line>
//             <line x1="0.0" y1="42.444842173771576" x2="432.9845414590389" y2="42.44484217377

// %%
val adoptionRate = years.map { year ->
    (cumulativeKotlinRepos.filter { it["year"] == year }[0]["yearly_count"].toString().toFloat() /
            cumulativeJvmRepos.filter { it["year"] == year }[0]["yearly_count"].toString().toFloat() ) * 100
}

val adoptionRateWithStart = adoptionRate.toMutableList()
adoptionRateWithStart.add(0, 0F)
val yearsWithStart = years.toMutableList()
yearsWithStart.add(0, "2018")

val adoptionRateFrame = dataFrameOf(
    "year" to yearsWithStart,
    "rate" to adoptionRateWithStart
)

adoptionRateFrame.plot() {
    line {
        x("year"){
            axis.name = "Calendar year"
        }
        y("rate"){
            axis.name = "Percent"
        }
        color = Color.ORANGE
    }
}
// Out:
//             <iframe src='about:blank' style='border:none !important;' width='600' height='400' srcdoc="&lt;html lang=&quot;en&quot;>
//    &lt;head>
//        &lt;meta charset=&quot;UTF-8&quot;>
//        &lt;style> html, body { margin: 0; overflow: hidden; } &lt;/style>
//        &lt;script type=&quot;text/javascript&quot; data-lets-plot-script=&quot;library&quot; src=&quot;https://cdn.jsdelivr.net/gh/JetBrains/lets-plot@v4.3.3/js-package/distr/lets-plot.min.js&quot;>&lt;/script>
//    &lt;/head>
//    &lt;body>
//           &lt;div id=&quot;TRxA5s&quot;>&lt;/div>
//    &lt;script type=&quot;text/javascript&quot; data-lets-plot-script=&quot;plot&quot;>
//        var plotSpec={
// &quot;mapping&quot;:{
// },
// &quot;data&quot;:{
// &quot;year&quot;:[&quot;2018&quot;,&quot;2019&quot;,&quot;2020&quot;,&quot;2021&quot;,&quot;2022&quot;,&quot;2023&quot;,&quot;2024&quot;],
// &quot;rate&quot;:[0.0,6.560364246368408,6.4453125,8.32025146484375,6.723891258239746,10.746606826782227,11.052631378173828]
// },
// &quot;kind&quot;:&quot;plot&quot;,
// &quot;scales&quot;:[{
// &quot;aesthetic&quot;:&quot;x&quot;,
// &quot;discrete&quot;:true,
// &quot;name&quot;:&quot;Calendar year&quot;
// },{
// &quot;aesthetic&quot;:&quot;y&quot;,
// &quot;name&quot;:&quot;Percent&quot;,
// &quot;limits&quot;:[null,null]
// }],
// &quot;layers&quot;:[{
// &quot;mapping&quot;:{
// &quot;x&quot;:&quot;year&quot;,
// &quot;y&quot;:&quot;rate&quot;
// },
// &quot;stat&quot;:&quot;identity&quot;,
// &quot;color&quot;:&quot;#fc8452&quot;,
// &quot;sampling&quot;:&quot;none&quot;,
// &quot;position&quot;:&quot;identity&quot;,
// &quot;geom&quot;:&quot;line&quot;,
// &quot;data&quot;:{
// }
// }]
// };
//        var plotContainer = document.getElementById(&quot;TRxA5s&quot;);
//        LetsPlot.buildPlotFromProcessedSpecs(plotSpec, -1, -1, plotContainer);
//    &lt;/script>
//    &lt;/body>
// &lt;/html>"></iframe>            <svg xmlns="http://www.w3.org/2000/svg" xmlns:xlink="http://www.w3.org/1999/xlink" display="block" class="plt-container" id=e2834dd4-566a-479d-af44-ee48f137b1e1 width="100%" height="100%" style="max-width: 600.0px; max-height: 400.0px;" viewBox="0 0 600.0 400.0" preserveAspectRatio="xMinYMin meet">
//   <style type="text/css">
//   .plt-container {
//    font-family: Lucida Grande, sans-serif;
//    user-select: none;
//    -webkit-user-select: none;
//    -moz-user-select: none;
//    -ms-user-select: none;
// }
// text {
//    text-rendering: optimizeLegibility;
// }
// #pcKbgPj .plot-title {
//    fill: #474747;
//    font-family: Lucida Grande, sans-serif;
//    font-size: 16.0px;
//    font-weight: normal;
//    font-style: normal;
// }
// #pcKbgPj .plot-subtitle {
//    fill: #474747;
//    font-family: Lucida Grande, sans-serif;
//    font-size: 15.0px;
//    font-weight: normal;
//    font-style: normal;
// }
// #pcKbgPj .plot-caption {
//    fill: #474747;
//    font-family: Lucida Grande, sans-serif;
//    font-size: 13.0px;
//    font-weight: normal;
//    font-style: normal;
// }
// #pcKbgPj .legend-title {
//    fill: #474747;
//    font-family: Lucida Grande, sans-serif;
//    font-size: 15.0px;
//    font-weight: normal;
//    font-style: normal;
// }
// #pcKbgPj .legend-item {
//    fill: #474747;
//    font-family: Lucida Grande, sans-serif;
//    font-size: 13.0px;
//    font-weight: normal;
//    font-style: normal;
// }
// #pcKbgPj .axis-title-x {
//    fill: #474747;
//    font-family: Lucida Grande, sans-serif;
//    font-size: 15.0px;
//    font-weight: normal;
//    font-style: normal;
// }
// #pcKbgPj .axis-text-x {
//    fill: #474747;
//    font-family: Lucida Grande, sans-serif;
//    font-size: 13.0px;
//    font-weight: normal;
//    font-style: normal;
// }
// #dqRKT7l .axis-tooltip-text-x {
//    fill: #ffffff;
//    font-family: Lucida Grande, sans-serif;
//    font-size: 13.0px;
//    font-weight: normal;
//    font-style: normal;
// }
// #pcKbgPj .axis-title-y {
//    fill: #474747;
//    font-family: Lucida Grande, sans-serif;
//    font-size: 15.0px;
//    font-weight: normal;
//    font-style: normal;
// }
// #pcKbgPj .axis-text-y {
//    fill: #474747;
//    font-family: Lucida Grande, sans-serif;
//    font-size: 13.0px;
//    font-weight: normal;
//    font-style: normal;
// }
// #dqRKT7l .axis-tooltip-text-y {
//    fill: #ffffff;
//    font-family: Lucida Grande, sans-serif;
//    font-size: 13.0px;
//    font-weight: normal;
//    font-style: normal;
// }
// #pcKbgPj .facet-strip-text-x {
//    fill: #474747;
//    font-family: Lucida Grande, sans-serif;
//    font-size: 13.0px;
//    font-weight: normal;
//    font-style: normal;
// }
// #pcKbgPj .facet-strip-text-y {
//    fill: #474747;
//    font-family: Lucida Grande, sans-serif;
//    font-size: 13.0px;
//    font-weight: normal;
//    font-style: normal;
// }
// #dqRKT7l .tooltip-text {
//    fill: #474747;
//    font-family: Lucida Grande, sans-serif;
//    font-size: 13.0px;
//    font-weight: normal;
//    font-style: normal;
// }
// #dqRKT7l .tooltip-title {
//    fill: #474747;
//    font-family: Lucida Grande, sans-serif;
//    font-size: 13.0px;
//    font-weight: bold;
//    font-style: normal;
// }
// #dqRKT7l .tooltip-label {
//    fill: #474747;
//    font-family: Lucida Grande, sans-serif;
//    font-size: 13.0px;
//    font-weight: bold;
//    font-style: normal;
// }
//
//   </style>
//   <g id="pcKbgPj">
//     <path fill-rule="evenodd" fill="rgb(255,255,255)" fill-opacity="1.0" d="M0.0 0.0 L0.0 400.0 L600.0 400.0 L600.0 0.0 Z">
//     </path>
//     <g transform="translate(29.5 6.5 ) ">
//       <g>
//         <g transform="translate(21.961210910936405 0.0 ) ">
//           <g>
//             <line x1="16.938712159033237" y1="0.0" x2="16.938712159033237" y2="341.0" stroke="rgb(233,233,233)" stroke-opacity="1.0" stroke-width="1.0" fill="none">
//             </line>
//             <line x1="101.63227295419941" y1="0.0" x2="101.63227295419941" y2="341.0" stroke="rgb(233,233,233)" stroke-opacity="1.0" stroke-width="1.0" fill="none">
//             </line>
//             <line x1="186.3258337493656" y1="0.0" x2="186.3258337493656" y2="341.0" stroke="rgb(233,233,233)" stroke-opacity="1.0" stroke-width="1.0" fill="none">
//             </line>
//             <line x1="271.0193945445318" y1="0.0" x2="271.0193945445318" y2="341.0" stroke="rgb(233,233,233)" stroke-opacity="1.0" stroke-width="1.0" fill="none">
//             </line>
//             <line x1="355.71295533969794" y1="0.0" x2="355.71295533969794" y2="341.0" stroke="rgb(233,233,233)" stroke-opacity="1.0" stroke-width="1.0" fill="none">
//             </line>
//             <line x1="440.4065161348641" y1="0.0" x2="440.4065161348641" y2="341.0" stroke="rgb(233,233,233)" stroke-opacity="1.0" stroke-width="1.0" fill="none">
//             </line>
//             <line x1="525.1000769300304" y1="0.0" x2="525.1000769300304" y2="341.0" stroke="rgb(233,233,233)" stroke-opacity="1.0" stroke-width="1.0" fill="none">
//             </line>
//           </g>
//         </g>
//         <g transform="translate(21.961210910936405 0.0 ) ">
//           <g>
//             <line x1="0.0" y1="325.5" x2="542.0387890890636" y2="325.5" stroke="rgb(233,233,233)" stroke-opacity="1.0" stroke-width="1.0" fill="none">
//             </line>
//             <line x1="0.0" y1="269.40476088577924" x2="542.0387890890636" y2="269.40476088577924" stroke="rgb(233,233,233)" stroke-opacity="1.0" stroke-width="1.0" fill="none">
//             </line>
//             <line x1="0.0" y1="213.3095217715585" x2="542.0387890890636" y2="213.3095217715585" stroke="rgb(233,233,233)" stroke-opacity="1.0" stroke-width="1.0" fill="none">
//             </line>
//             <line x1="0.0" y1="157.21428265733778" x2="542.0387890890636" y2="157.21428265733778" stroke="rgb(233,233,233)" stroke-opacity="1.0" stroke-width="1.0" fill="none">
//             </line>
//             <line x1="0.0" y1="101.11904354311702" x2="542.0387890890636" y2="101.11904354311702" stroke="rgb(233,233,233)" stroke-opacity="1.0" stroke-width="1.0" fill="none">
//             </line>
//             <line x1="0.0" y1="45.023804428896256" x2="542.0387890890636" y2="45.023804428896256" stroke="rgb(233,233,233)" stroke-opacity="1.0" stroke-width="1.0" fill="none">
//             </line>
//           </g>
//         </g>
//       </g>
//       <g clip-path="url(#cuEVjPi)" clip-bounds-jfx="[rect (21.961210910936405, 0.0), (542.0387890890636, 341.0)]">
//         <g transform="translate(21.961210910936405 0.0 ) ">
//           <g>
//             <g>

// %%
// We want the distribution of different types of Kotlin repos

val kotlinRepos = jvm_active_repositories.filter { it["is_kotlin"] == 1}

val androidRepos = kotlinRepos.filter { it["is_android"] == 1 }
val javaNonAndroid = kotlinRepos.filter { it["is_android"] == 0 && it["is_java"] == 1 }
val pureKotlinRepos = kotlinRepos.filter { it["is_android"] == 0 && it["is_java"] == 0 }

// Validating I captured everything
println(androidRepos.rowsCount() + javaNonAndroid.rowsCount() + pureKotlinRepos.rowsCount() )


val repository_type by columnOf("Android", "Pure Kotlin", "Other")
val count by columnOf(androidRepos.rowsCount(), pureKotlinRepos.rowsCount(), javaNonAndroid.rowsCount())
val df = dataFrameOf(repository_type, count)

df.plot {
    pie {
        slice(count)
        fillColor(repository_type) {
            scale = categorical(
                "Android" to Color.GREEN,
                "Pure Kotlin" to Color.PURPLE,
                "Other" to Color.ORANGE
            )
        }
        size = 33.0
        hole = 0.8
        alpha = 0.8
    }
    layout {
        style(Style.Void)
    }
}
// Out:
// 435
//             <iframe src='about:blank' style='border:none !important;' width='600' height='400' srcdoc="&lt;html lang=&quot;en&quot;>
//    &lt;head>
//        &lt;meta charset=&quot;UTF-8&quot;>
//        &lt;style> html, body { margin: 0; overflow: hidden; } &lt;/style>
//        &lt;script type=&quot;text/javascript&quot; data-lets-plot-script=&quot;library&quot; src=&quot;https://cdn.jsdelivr.net/gh/JetBrains/lets-plot@v4.3.3/js-package/distr/lets-plot.min.js&quot;>&lt;/script>
//    &lt;/head>
//    &lt;body>
//           &lt;div id=&quot;iDibOa&quot;>&lt;/div>
//    &lt;script type=&quot;text/javascript&quot; data-lets-plot-script=&quot;plot&quot;>
//        var plotSpec={
// &quot;mapping&quot;:{
// },
// &quot;data&quot;:{
// &quot;count&quot;:[137.0,177.0,121.0],
// &quot;repository_type&quot;:[&quot;Android&quot;,&quot;Pure Kotlin&quot;,&quot;Other&quot;]
// },
// &quot;kind&quot;:&quot;plot&quot;,
// &quot;scales&quot;:[{
// &quot;aesthetic&quot;:&quot;fill&quot;,
// &quot;values&quot;:[&quot;#3ba272&quot;,&quot;#9a60b4&quot;,&quot;#fc8452&quot;],
// &quot;limits&quot;:[&quot;Android&quot;,&quot;Pure Kotlin&quot;,&quot;Other&quot;]
// }],
// &quot;layers&quot;:[{
// &quot;hole&quot;:0.8,
// &quot;mapping&quot;:{
// &quot;slice&quot;:&quot;count&quot;,
// &quot;fill&quot;:&quot;repository_type&quot;
// },
// &quot;stat&quot;:&quot;identity&quot;,
// &quot;size&quot;:33.0,
// &quot;sampling&quot;:&quot;none&quot;,
// &quot;alpha&quot;:0.8,
// &quot;position&quot;:&quot;identity&quot;,
// &quot;geom&quot;:&quot;pie&quot;,
// &quot;data&quot;:{
// }
// }],
// &quot;theme&quot;:{
// &quot;name&quot;:&quot;classic&quot;,
// &quot;axis&quot;:{
// &quot;blank&quot;:true
// },
// &quot;line&quot;:{
// &quot;blank&quot;:true
// },
// &quot;axis_ontop&quot;:false,
// &quot;axis_ontop_y&quot;:false,
// &quot;axis_ontop_x&quot;:false
// }
// };
//        var plotContainer = document.getElementById(&quot;iDibOa&quot;);
//        LetsPlot.buildPlotFromProcessedSpecs(plotSpec, -1, -1, plotContainer);
//    &lt;/script>
//    &lt;/body>
// &lt;/html>"></iframe>            <svg xmlns="http://www.w3.org/2000/svg" xmlns:xlink="http://www.w3.org/1999/xlink" display="block" class="plt-container" id=c187f2c2-f09d-47ee-823a-f2b9b26633e3 width="100%" height="100%" style="max-width: 600.0px; max-height: 400.0px;" viewBox="0 0 600.0 400.0" preserveAspectRatio="xMinYMin meet">
//   <style type="text/css">
//   .plt-container {
//    font-family: Lucida Grande, sans-serif;
//    user-select: none;
//    -webkit-user-select: none;
//    -moz-user-select: none;
//    -ms-user-select: none;
// }
// text {
//    text-rendering: optimizeLegibility;
// }
// #pfHh0qh .plot-title {
//    fill: #474747;
//    font-family: Lucida Grande, sans-serif;
//    font-size: 16.0px;
//    font-weight: normal;
//    font-style: normal;
// }
// #pfHh0qh .plot-subtitle {
//    fill: #474747;
//    font-family: Lucida Grande, sans-serif;
//    font-size: 15.0px;
//    font-weight: normal;
//    font-style: normal;
// }
// #pfHh0qh .plot-caption {
//    fill: #474747;
//    font-family: Lucida Grande, sans-serif;
//    font-size: 13.0px;
//    font-weight: normal;
//    font-style: normal;
// }
// #pfHh0qh .legend-title {
//    fill: #474747;
//    font-family: Lucida Grande, sans-serif;
//    font-size: 15.0px;
//    font-weight: normal;
//    font-style: normal;
// }
// #pfHh0qh .legend-item {
//    fill: #474747;
//    font-family: Lucida Grande, sans-serif;
//    font-size: 13.0px;
//    font-weight: normal;
//    font-style: normal;
// }
// #pfHh0qh .axis-title-x {
//    fill: #474747;
//    font-family: Lucida Grande, sans-serif;
//    font-size: 15.0px;
//    font-weight: normal;
//    font-style: normal;
// }
// #pfHh0qh .axis-text-x {
//    fill: #474747;
//    font-family: Lucida Grande, sans-serif;
//    font-size: 13.0px;
//    font-weight: normal;
//    font-style: normal;
// }
// #dB5T9Nz .axis-tooltip-text-x {
//    fill: #ffffff;
//    font-family: Lucida Grande, sans-serif;
//    font-size: 13.0px;
//    font-weight: normal;
//    font-style: normal;
// }
// #pfHh0qh .axis-title-y {
//    fill: #474747;
//    font-family: Lucida Grande, sans-serif;
//    font-size: 15.0px;
//    font-weight: normal;
//    font-style: normal;
// }
// #pfHh0qh .axis-text-y {
//    fill: #474747;
//    font-family: Lucida Grande, sans-serif;
//    font-size: 13.0px;
//    font-weight: normal;
//    font-style: normal;
// }
// #dB5T9Nz .axis-tooltip-text-y {
//    fill: #ffffff;
//    font-family: Lucida Grande, sans-serif;
//    font-size: 13.0px;
//    font-weight: normal;
//    font-style: normal;
// }
// #pfHh0qh .facet-strip-text-x {
//    fill: #474747;
//    font-family: Lucida Grande, sans-serif;
//    font-size: 13.0px;
//    font-weight: normal;
//    font-style: normal;
// }
// #pfHh0qh .facet-strip-text-y {
//    fill: #474747;
//    font-family: Lucida Grande, sans-serif;
//    font-size: 13.0px;
//    font-weight: normal;
//    font-style: normal;
// }
// #dB5T9Nz .tooltip-text {
//    fill: #474747;
//    font-family: Lucida Grande, sans-serif;
//    font-size: 13.0px;
//    font-weight: normal;
//    font-style: normal;
// }
// #dB5T9Nz .tooltip-title {
//    fill: #474747;
//    font-family: Lucida Grande, sans-serif;
//    font-size: 13.0px;
//    font-weight: bold;
//    font-style: normal;
// }
// #dB5T9Nz .tooltip-label {
//    fill: #474747;
//    font-family: Lucida Grande, sans-serif;
//    font-size: 13.0px;
//    font-weight: bold;
//    font-style: normal;
// }
//
//   </style>
//   <g id="pfHh0qh">
//     <path fill-rule="evenodd" fill="rgb(255,255,255)" fill-opacity="1.0" d="M0.0 0.0 L0.0 400.0 L600.0 400.0 L600.0 0.0 Z">
//     </path>
//     <g transform="translate(6.5 6.5 ) ">
//       <g>
//         <g transform="">
//           <g>
//           </g>
//         </g>
//         <g transform="">
//           <g>
//           </g>
//         </g>
//         <g transform="translate(0.0 387.0 ) ">
//         </g>
//         <g transform="">
//         </g>
//       </g>
//       <g clip-path="url(#cAsGDtr)" clip-bounds-jfx="[rect (0.0, 0.0), (445.6459544983765, 387.0)]">
//         <g transform="">
//           <g>
//             <g>
//               <g>
//                 <path d="M101.66044428743984 245.87977287363157 L71.36981104700274 258.97471609203944 A165.0 165.0 0.0 0 1 222.82297724918823 28.5 L222.82297724918823 61.5 A132.0 132.0 0.0 0 0 101.66044428743984 245.87977287363157 " fill="rgb(59,162,114)" stroke-width="1.0" fill-opacity="0.8">
//                 </path>
//               </g>
//               <g>
//                 <path d="M222.82297724918823 61.5 L222.82297724918823 28.5 A165.0 165.0 0.0 0 1 313.9339794737589 331.06374985305644 L295.7117790288448 303.5509998824451 A132.0 132.0 0.0 0 0 222.82297724918823 61.5 " fill="rgb(154,96,180)" stroke-width="1.0" fill-opacity="0.8">
//                 </path>
//               </g>
//               <g>
//                 <path d="M295.7117790288448 303.5509998824451 L313.9339794737589 331.06374985305644 A165.0 165.0 0.0 0 1 71.36981104700283 258.97471609203967 L101.6604442874399 245.8797728736317 A132.0 132.0 0.0 0 0 295.7117790288448 303.5509998824451 " fill="rgb(252,132,82)" stroke-width="1.0" fill-opacity="0.8">
//                 </path>
//               </g>
//               <g>
//                 <path d="M71.36981104700274 258.97471609203944 A165.0 165.0 0.0 0 1 222.82297724918823 28.5 M222.82297724918823 61.5 A132.0 132.0 0.0 0 0 101.66044428743984 245.87977287363157 " fill="none" stroke-width="0.75" stroke="rgb(255,255,255)" stroke-opacity="1.0">
//                 </path>
//               </g>
//               <g>
//                 <path d="M222.82297724918823 28.5 A165.0 165.0 0.0 0 1 313.9339794737589 331.06374985305644 M295.7117790288448 303.5509998824451 A132.0 132.0 0.0 0 0 222.82297724918823 61.5 " fill="none" stroke-width="0.75" stroke="rgb(255,255,255)" stroke-opacity="1.0">
//                 </path>
//               </g>
//               <g>
//                 <path d="M313.9339794737589 331.06374985305644 A165.0 165.0 0.0 0 1 71.36981104700283 258.97471609203967 M101.6604442874399 245.8797728736317 A132.0 132.0 0.0 0 0 295.7117790288448 303.5509998824451 " fill="none" stroke-width="0.75" stroke="rgb(255,255,255)" stroke-opacity="1.0">
//                 </path>
//               </g>
//               <g>
//                 <path d="M102.00465602880845 245.73096670069512 L71.02559930563413 259.1235222649759 M222.82297724918823 61.875 L222.82297724918823 28.125 " fill="none" stroke-width="0.75" stroke="rgb(255

// %%
import java.time.LocalDateTime
import java.time.LocalDate

// Here we want to see the ratio JVM / Kotlin segregated by location

val nonEuropeKotlinRepos = kotlinRepos.filter{ it["location"] == "World"}
val europeKotlinRepos = kotlinRepos.filter{ it["location"] == "Europe"}

println(kotlinRepos.rowsCount())
println(nonEuropeKotlinRepos.rowsCount())
println(europeKotlinRepos.rowsCount())

val europeRatio = (europeKotlinRepos.rowsCount().toDouble() / kotlinRepos.rowsCount().toDouble()) * 100

println("Overall the ratio is : ${europeRatio.toInt()}% in Europe and ${(100 - europeRatio).toInt()}% outside")

// Ok and now only for last year
val now = LocalDateTime.now()
val aYearAgo = now.minusYears(1)

println(jvm_active_repositories.rowsCount())

val jvmRepos2024 = jvm_active_repositories.filter {
    it["oldest_commit"] != null &&
            LocalDate.parse(it["oldest_commit"].toString().split(" ")[0]).atTime(23, 59) > aYearAgo
}

println(jvmRepos2024.rowsCount())

val jvmReposEurope2024 = jvmRepos2024.filter{ it["location"] == "INGEurCDaaS01"}
val jvmReposNonEurope2024 = jvmRepos2024.filter{ it["location"] == "IngCDaaS"}

println(jvmReposEurope2024.rowsCount())
println(jvmReposNonEurope2024.rowsCount())

println("###")
val nonEuropeKotlinRepos2024 = jvmReposNonEurope2024.filter{ it["is_kotlin"] == 1}
val europeKotlinRepos2024 = jvmReposEurope2024.filter{ it["is_kotlin"] == 1}

println(europeKotlinRepos2024.rowsCount())
println(nonEuropeKotlinRepos2024.rowsCount())

val europeKotlinRatio2024 = (europeKotlinRepos2024.rowsCount().toDouble() / jvmReposEurope2024.rowsCount().toDouble()) * 100
val nonEuropeKotlinRatio2024 = (nonEuropeKotlinRepos2024.rowsCount().toDouble() / jvmReposNonEurope2024.rowsCount().toDouble()) * 100

println("Finally the ratio is : ${europeKotlinRatio2024.toInt()}% in Europe and ${nonEuropeKotlinRatio2024.toInt()}% outside")
// Out:
// 435
// 0
// 0
// Overall the ratio is : 0% in Europe and 100% outside
// 5497
// 533
// 414
// 119
// ###
// 46
// 14
// Finally the ratio is : 11% in Europe and 11% outside
